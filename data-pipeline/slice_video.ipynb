# %% [markdown]
# # Slice Series of Videos with Array

# %%
#base_dir = "C:\\Users\\ASABUNCUOGLU13\\Documents\\data\\vol07"
base_dir = "D:\\vol08\\4-5\\"
video_name = "in"

# %%
video_slices = [
    ["00:00:50", "00:05:40"], #0
    ["00:05:40", "00:10:40"], #1
    ["00:10:40", "00:15:40"], #2
    ["00:15:40", "00:20:40"], #3
    ["00:20:40", "00:25:40"], #4
    ["00:25:40", "00:30:40"], #5
    ["00:30:40", "00:35:40"], #6
    ["00:35:40", "00:40:40"], #7
    ["00:40:40", "00:44:40"], #8
    ["00:44:40", "00:48:29"], #9
]

# %%
#data_dir = "C:\\Users\\ASABUNCUOGLU13\\Documents\\data\\vol06\\"
data_dir = base_dir

# %%
#!mkdir {data_dir}

# %%
import os

i = 0

for slice in video_slices:
    #data_dir = os.path.join(base_dir, output_folder)
    # !ffmpeg -ss  {slice[0]} -to {slice[1]} -i {base_dir + "\\" + video_name}.mp4 -c copy {data_dir + "\\v" + str(i)}.mp4
    i += 1
# Out:
# ffmpeg version 5.0.1-essentials_build-www.gyan.dev Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 11.2.0 (Rev7, Built by MSYS2 project)
# ...

# %% [markdown]
# # Cut Individual Video

# %%
#base_dir = "C:\\Users\\ASABUNCUOGLU13\\Documents\\data\\vol02\\cansu-berk"
base_dir = "D:\\vol04\\face\\3"
video_name = "20221031_180907"
output_name = "v0"

# %%
# !ffmpeg -ss  00:05:08 -to 00:10:25 -i {base_dir + "\\" + video_name}.mp4 -c copy {base_dir + "\\" + output_name}.mp4
