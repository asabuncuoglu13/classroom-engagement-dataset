# %%
#base_dir = "D:\\vol05\\3\\slices"
base_dir = "C:\\Users\\ASABUNCUOGLU13\\Documents\\data\\vol08"
out_dir = "C:\\Users\\ASABUNCUOGLU13\\Documents\\data\\vol08\\speech"

# %%
import os

for i in range(0,10):
    # !ffmpeg -i {base_dir + "\\v" + str(i)}.mp4 -vn -acodec pcm_s16le -ar 44100 -ac 1 -af "afftdn=nf=-25" {out_dir + "\\" + str(i)}.wav
# Out:
# ffmpeg version 5.0.1-essentials_build-www.gyan.dev Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 11.2.0 (Rev7, Built by MSYS2 project)
# ...

# %%
for i in range(0,10):
    # !whisper {out_dir + "\\" + str(i)}.wav --model small -o {out_dir + "\\transcript"}
# Out:
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: English
# [00:00.000 --> 00:09.160]  This is the first video in what is a playlist of many, many, many, probably too many videos
# [00:09.160 --> 00:10.160]  about learning to code.
# [00:10.160 --> 00:15.000]  If you have never written any code before, if you've never programmed before, if you
# [00:15.000 --> 00:21.160]  don't know anything about programming, it's my intention for this playlist to be for you.
# [00:21.160 --> 00:23.360]  So this is the first introductory video.
# [00:23.360 --> 00:30.520]  I'm just going to talk about the pieces of the puzzle that I'm going to use to show you
# [00:30.520 --> 00:34.520]  where all those things are and kind of a little bit about the history of those things, just
# [00:34.520 --> 00:37.720]  to get started in learning to code.
# [00:37.720 --> 00:38.720]  Learning to code.
# ...
