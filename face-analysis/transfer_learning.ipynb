# %% [markdown]
# # Transfer learning and fine-tuning

# %% [markdown]
# This notebook is forked from [Tensorflow Tutorial](https://www.tensorflow.org/tutorials/images/transfer_learning)

# %%
# !export TF_ENABLE_ONEDNN_OPTS=1
# !export TF_GPU_ALLOCATOR=cuda_malloc_async

import os
import sys
from glob import glob
sys.path.append('../code/tfkeras-vggface/')
sys.path.append('../code/LCNN/')

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras import  Model
from tensorflow.keras.layers import Input, Flatten, Dense
from tfkeras_vggface.vggface import VGGFace
from tfkeras_vggface import utils
from tensorflow.keras.preprocessing import image

from src.model import layers as lcnn_layers
from src.model import lcnn

# %%
# !nvidia-smi
# Out:
# Mon Feb  6 17:32:32 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.57.02    Driver Version: 470.57.02    CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:1C:00.0 Off |                    0 |
# | N/A   33C    P0    25W /  70W |      0MiB / 15109MiB |      6%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# ### Data download

# %% [markdown]
# In this tutorial, you will use a dataset containing several thousand images of cats and dogs. Download and extract a zip file containing the images, then create a `tf.data.Dataset` for training and validation using the `tf.keras.utils.image_dataset_from_directory` utility. You can learn more about loading images in this [tutorial](https://www.tensorflow.org/tutorials/load_data/images).

# %%
data_dirs = []
for i in range(4,9):
    data_dirs.append(glob(os.path.join('../face-levels/%d/' % i, "*")))

# %%
import pathlib
data_dir = pathlib.Path('../face-levels/4/3')

BATCH_SIZE = 32
IMG_SIZE = (160, 160)

train_dataset = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=IMG_SIZE,
  batch_size=BATCH_SIZE)
# Out:
# Found 1036 files belonging to 5 classes.
# Using 829 files for training.
# 2023-02-06 17:32:34.976817: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-06 17:32:37.783458: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13781 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:1c:00.0, compute capability: 7.5

# %%
validation_dataset = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=IMG_SIZE,
  batch_size=BATCH_SIZE)
# Out:
# Found 1036 files belonging to 5 classes.
# Using 207 files for validation.

# %% [markdown]
# Show the first nine images and labels from the training set:

# %%
class_names = train_dataset.class_names

plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# As the original dataset doesn't contain a test set, you will create one. To do so, determine how many batches of data are available in the validation set using `tf.data.experimental.cardinality`, then move 20% of them to a test set.

# %%
val_batches = tf.data.experimental.cardinality(validation_dataset)
test_dataset = validation_dataset.take(val_batches // 5)
validation_dataset = validation_dataset.skip(val_batches // 5)

# %%
print('Number of validation batches: %d' % tf.data.experimental.cardinality(validation_dataset))
print('Number of test batches: %d' % tf.data.experimental.cardinality(test_dataset))
# Out:
# Number of validation batches: 6
# Number of test batches: 1

# %% [markdown]
# ### Configure the dataset for performance

# %% [markdown]
# Use buffered prefetching to load images from disk without having I/O become blocking. To learn more about this method see the [data performance](https://www.tensorflow.org/guide/data_performance) guide.

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Use data augmentation

# %% [markdown]
# When you don't have a large image dataset, it's a good practice to artificially introduce sample diversity by applying random, yet realistic, transformations to the training images, such as rotation and horizontal flipping. This helps expose the model to different aspects of the training data and reduce [overfitting](https://www.tensorflow.org/tutorials/keras/overfit_and_underfit). You can learn more about data augmentation in this [tutorial](https://www.tensorflow.org/tutorials/images/data_augmentation).

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip('horizontal'),
  tf.keras.layers.RandomRotation(0.2),
])

# %% [markdown]
# Note: These layers are active only during training, when you call `Model.fit`. They are inactive when the model is used in inference mode in `Model.evaluate` or `Model.fit`.

# %% [markdown]
# Let's repeatedly apply these layers to the same image and see the result.

# %%
for image, _ in train_dataset.take(1):
  plt.figure(figsize=(10, 10))
  first_image = image[0]
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
    plt.imshow(augmented_image[0] / 255)
    plt.axis('off')
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:5 out of the last 5 calls to <function pfor.<locals>.f at 0x2acc668bf8b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:6 out of the last 6 calls to <function pfor.<locals>.f at 0x2acc669635e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %% [markdown]
# ### Rescale pixel values
#
# In a moment, you will download `tf.keras.applications.MobileNetV2` for use as your base model. This model expects pixel values in `[-1, 1]`, but at this point, the pixel values in your images are in `[0, 255]`. To rescale them, use the preprocessing method included with the model.

# %%
preprocess_input = tf.keras.applications.mobilenet_v2.preprocess_input

# %% [markdown]
# Note: Alternatively, you could rescale pixel values from `[0, 255]` to `[-1, 1]` using `tf.keras.layers.Rescaling`.

# %%
rescale = tf.keras.layers.Rescaling(1./127.5, offset=-1)

# %% [markdown]
# Note: If using other `tf.keras.applications`, be sure to check the API doc to determine if they expect pixels in `[-1, 1]` or `[0, 1]`, or use the included `preprocess_input` function.

# %% [markdown]
# ## Create the base model from the pre-trained convnets
# You will create the base model from the **MobileNet V2** model developed at Google. This is pre-trained on the ImageNet dataset, a large dataset consisting of 1.4M images and 1000 classes. ImageNet is a research training dataset with a wide variety of categories like `jackfruit` and `syringe`. This base of knowledge will help us classify cats and dogs from our specific dataset.
#
# First, you need to pick which layer of MobileNet V2 you will use for feature extraction. The very last classification layer (on "top", as most diagrams of machine learning models go from bottom to top) is not very useful. Instead, you will follow the common practice to depend on the very last layer before the flatten operation. This layer is called the "bottleneck layer". The bottleneck layer features retain more generality as compared to the final/top layer.
#
# First, instantiate a MobileNet V2 model pre-loaded with weights trained on ImageNet. By specifying the **include_top=False** argument, you load a network that doesn't include the classification layers at the top, which is ideal for feature extraction.

# %%
# Create the base model from the pre-trained model MobileNet V2
IMG_SHAPE = IMG_SIZE + (3,)


#base_model = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE, include_top=False, weights='imagenet')

base_model = VGGFace(include_top=False, input_shape=IMG_SHAPE, pooling='max')

# %% [markdown]
# This feature extractor converts each `160x160x3` image into a `5x5x1280` block of features. Let's see what it does to an example batch of images:

# %%
image_batch, label_batch = next(iter(train_dataset))
feature_batch = base_model(image_batch)
print(feature_batch.shape)
# Out:
# 2023-02-06 17:32:57.392493: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8101
# (32, 512)

# %% [markdown]
# ## Feature extraction
# In this step, you will freeze the convolutional base created from the previous step and to use as a feature extractor. Additionally, you add a classifier on top of it and train the top-level classifier.

# %% [markdown]
# ### Freeze the convolutional base

# %% [markdown]
# It is important to freeze the convolutional base before you compile and train the model. Freezing (by setting layer.trainable = False) prevents the weights in a given layer from being updated during training. MobileNet V2 has many layers, so setting the entire model's `trainable` flag to False will freeze all of them.

# %%
base_model.trainable = False

# %% [markdown]
# ### Important note about BatchNormalization layers
#
# Many models contain `tf.keras.layers.BatchNormalization` layers. This layer is a special case and precautions should be taken in the context of fine-tuning, as shown later in this tutorial.
#
# When you set `layer.trainable = False`, the `BatchNormalization` layer will run in inference mode, and will not update its mean and variance statistics.
#
# When you unfreeze a model that contains BatchNormalization layers in order to do fine-tuning, you should keep the BatchNormalization layers in inference mode by passing `training = False` when calling the base model. Otherwise, the updates applied to the non-trainable weights will destroy what the model has learned.
#
# For more details, see the [Transfer learning guide](https://www.tensorflow.org/guide/keras/transfer_learning).

# %%
# Let's take a look at the base model architecture
base_model.summary()
# Out:
# Model: "vggface_vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 160, 160, 3)]     0
#
#  conv1_1 (Conv2D)            (None, 160, 160, 64)      1792
#
#  conv1_2 (Conv2D)            (None, 160, 160, 64)      36928
#
#  pool1 (MaxPooling2D)        (None, 80, 80, 64)        0
#
#  conv2_1 (Conv2D)            (None, 80, 80, 128)       73856
#
#  conv2_2 (Conv2D)            (None, 80, 80, 128)       147584
#
#  pool2 (MaxPooling2D)        (None, 40, 40, 128)       0
#
#  conv3_1 (Conv2D)            (None, 40, 40, 256)       295168
#
#  conv3_2 (Conv2D)            (None, 40, 40, 256)       590080
#
#  conv3_3 (Conv2D)            (None, 40, 40, 256)       590080
#
#  pool3 (MaxPooling2D)        (None, 20, 20, 256)       0
#
#  conv4_1 (Conv2D)            (None, 20, 20, 512)       1180160
#
#  conv4_2 (Conv2D)            (None, 20, 20, 512)       2359808
#
#  conv4_3 (Conv2D)            (None, 20, 20, 512)       2359808
#
#  pool4 (MaxPooling2D)        (None, 10, 10, 512)       0
#
#  conv5_1 (Conv2D)            (None, 10, 10, 512)       2359808
#
#  conv5_2 (Conv2D)            (None, 10, 10, 512)       2359808
#
#  conv5_3 (Conv2D)            (None, 10, 10, 512)       2359808
#
#  pool5 (MaxPooling2D)        (None, 5, 5, 512)         0
#
#  global_max_pooling2d (Globa  (None, 512)              0
#  lMaxPooling2D)
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# ### Add a classification head

# %% [markdown]
# To generate predictions from the block of features, average over the spatial `5x5` spatial locations, using a `tf.keras.layers.GlobalAveragePooling2D` layer to convert the features to  a single 1280-element vector per image.

# %% [markdown]
# Apply a `tf.keras.layers.Dense` layer to convert these features into a single prediction per image. You don't need an activation function here because this prediction will be treated as a `logit`, or a raw prediction value. Positive numbers predict class 1, negative numbers predict class 0.

# %%
prediction_layer = Sequential([
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.Dense(len(class_names))
])

# %% [markdown]
# Build a model by chaining together the data augmentation, rescaling, `base_model` and feature extractor layers using the [Keras Functional API](https://www.tensorflow.org/guide/keras/functional). As previously mentioned, use `training=False` as our model contains a `BatchNormalization` layer.

# %%
inputs = tf.keras.Input(shape=(160, 160, 3))
x = data_augmentation(inputs)
x = preprocess_input(x)
x = base_model(x, training=False)
x = layers.Dropout(0.2)(x)
print(x.get_shape())

#conv_2d_8 = lcnn.MaxOutConv2D(x, 64, kernel_size=1, strides=1, padding="same")
#batch_norm_8 = layers.BatchNormalization()(conv_2d_8)

#conv_2d_9 = lcnn.MaxOutConv2D(batch_norm_8, 64, kernel_size=3, strides=1, padding="same")
#maxpool_9 = layers.MaxPool2D(pool_size=(2, 2), strides=(2, 2))(conv_2d_9)
#flatten = layers.Flatten()(maxpool_9)

#dense_10 = lcnn.MaxOutDense(flatten, 160)
dense_10 = lcnn.MaxOutDense(x, 160)
batch_norm_10 = layers.BatchNormalization()(dense_10)
dropout_10 = layers.Dropout(0.75)(batch_norm_10)

outputs = layers.Dense(len(class_names), activation="softmax")(dropout_10)

##outputs = 
prediction_layer(x)
model = tf.keras.Model(inputs, outputs)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# (None, 512)

# %% [markdown]
# ### Compile the model
#
# Compile the model before training it. Since there are two classes, use the `tf.keras.losses.BinaryCrossentropy` loss with `from_logits=True` since the model provides a linear output.

# %%
base_learning_rate = 0.0001
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 160, 160, 3)]     0
#
#  sequential (Sequential)     (None, 160, 160, 3)       0
#
#  tf.math.truediv_2 (TFOpLamb  (None, 160, 160, 3)      0
#  da)
#
#  tf.math.subtract_2 (TFOpLam  (None, 160, 160, 3)      0
#  bda)
#
#  vggface_vgg16 (Functional)  (None, 512)               14714688
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 160)               82080
#
#  maxout (Maxout)             (None, 160)               0
#
#  batch_normalization (BatchN  (None, 160)              640
#  ormalization)
#
#  dropout_3 (Dropout)         (None, 160)               0
#
#  dense_3 (Dense)             (None, 5)                 805
#
# =================================================================
# Total params: 14,798,213
# Trainable params: 83,205
# Non-trainable params: 14,715,008
# _________________________________________________________________

# %% [markdown]
# The 2.5 million parameters in MobileNet are frozen, but there are 1.2 thousand _trainable_ parameters in the Dense layer. These are divided between two `tf.Variable` objects, the weights and biases.

# %%
len(model.trainable_variables)
# Out:
# 6

# %% [markdown]
# ### Train the model
#
# After training for 10 epochs, you should see ~94% accuracy on the validation set.

# %%
initial_epochs = 50

loss0, accuracy0 = model.evaluate(validation_dataset)
# Out:
# /kuacc/users/asabuncuoglu13/.conda/envs/tf-py38/lib/python3.8/site-packages/keras/backend.py:5585: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 6/6 [==============================] - 10s 422ms/step - loss: 1.7946 - accuracy: 0.0400

# %%
print("initial loss: {:.2f}".format(loss0))
print("initial accuracy: {:.2f}".format(accuracy0))
# Out:
# initial loss: 1.79
# initial accuracy: 0.04

# %%
history = model.fit(train_dataset,
                    epochs=initial_epochs,
                    validation_data=validation_dataset)
# Out:
# Epoch 1/50
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 2023-02-06 17:36:06.700327: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x2acd00016850 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-02-06 17:36:06.700363: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2023-02-06 17:36:06.795841: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-02-06 17:36:07.336702: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 26/26 [==============================] - 17s 456ms/step - loss: 3.4330 - accuracy: 0.1906 - val_loss: 1.7605 - val_accuracy: 0.0800
# Epoch 2/50
# 26/26 [==============================] - 5s 153ms/step - loss: 3.5222 - accuracy: 0.1930 - val_loss: 1.7125 - val_accuracy: 0.1429
# Epoch 3/50
# 26/26 [==============================] - 5s 143ms/step - loss: 3.2493 - accuracy: 0.2364 - val_loss: 1.6710 - val_accuracy: 0.1600
# Epoch 4/50
# 26/26 [==============================] - 5s 151ms/step - loss: 3.0468 - accuracy: 0.2509 - val_loss: 1.6019 - val_accuracy: 0.2686
# Epoch 5/50
# 26/26 [==============================] - 4s 136ms/step - loss: 3.1978 - accuracy: 0.2437 - val_loss: 1.5582 - val_accuracy: 0.3086
# Epoch 6/50
# 26/26 [==============================] - 4s 144ms/step - loss: 3.0220 - accuracy: 0.2545 - val_loss: 1.4989 - val_accuracy: 0.3886
# Epoch 7/50
# 26/26 [==============================] - 5s 153ms/step - loss: 2.8717 - accuracy: 0.2823 - val_loss: 1.4817 - val_accuracy: 0.4286
# Epoch 8/50
# 26/26 [==============================] - 4s 135ms/step - loss: 2.9755 - accuracy: 0.2859 - val_loss: 1.4567 - val_accuracy: 0.4229
# Epoch 9/50
# 26/26 [==============================] - 4s 146ms/step - loss: 2.7195 - accuracy: 0.2823 - val_loss: 1.4329 - val_accuracy: 0.4286
# Epoch 10/50
# 26/26 [==============================] - 4s 137ms/step - loss: 2.5575 - accuracy: 0.3269 - val_loss: 1.4140 - val_accuracy: 0.4286
# Epoch 11/50
# 26/26 [==============================] - 4s 142ms/step - loss: 2.8860 - accuracy: 0.2883 - val_loss: 1.4143 - val_accuracy: 0.4171
# Epoch 12/50
# 26/26 [==============================] - 4s 144ms/step - loss: 2.7889 - accuracy: 0.3064 - val_loss: 1.4495 - val_accuracy: 0.3829
# Epoch 13/50
# 26/26 [==============================] - 4s 135ms/step - loss: 2.5139 - accuracy: 0.3390 - val_loss: 1.3831 - val_accuracy: 0.4457
# Epoch 14/50
# 26/26 [==============================] - 4s 143ms/step - loss: 2.4948 - accuracy: 0.3172 - val_loss: 1.3857 - val_accuracy: 0.4629
# Epoch 15/50
# 26/26 [==============================] - 4s 138ms/step - loss: 2.4742 - accuracy: 0.3293 - val_loss: 1.3804 - val_accuracy: 0.4343
# Epoch 16/50
# 26/26 [==============================] - 4s 137ms/step - loss: 2.4479 - accuracy: 0.3305 - val_loss: 1.3581 - val_accuracy: 0.4514
# Epoch 17/50
# 26/26 [==============================] - 4s 139ms/step - loss: 2.4343 - accuracy: 0.3438 - val_loss: 1.3240 - val_accuracy: 0.4743
# Epoch 18/50
# 26/26 [==============================] - 4s 137ms/step - loss: 2.3938 - accuracy: 0.3378 - val_loss: 1.3164 - val_accuracy: 0.4743
# Epoch 19/50
# 26/26 [==============================] - 5s 143ms/step - loss: 2.4290 - accuracy: 0.3257 - val_loss: 1.3424 - val_accuracy: 0.4743
# Epoch 20/50
# 26/26 [==============================] - 4s 140ms/step - loss: 2.3947 - accuracy: 0.3583 - val_loss: 1.2889 - val_accuracy: 0.5029
# Epoch 21/50
# 26/26 [==============================] - 4s 135ms/step - loss: 2.1190 - accuracy: 0.3812 - val_loss: 1.3241 - val_accuracy: 0.4857
# Epoch 22/50
# 26/26 [==============================] - 4s 136ms/step - loss: 2.3232 - accuracy: 0.3426 - val_loss: 1.3227 - val_accuracy: 0.4857
# Epoch 23/50
# 26/26 [==============================] - 4s 136ms/step - loss: 2.3182 - accuracy: 0.3450 - val_loss: 1.3021 - val_accuracy: 0.4686
# Epoch 24/50
# 26/26 [==============================] - 5s 142ms/step - loss: 2.2117 - accuracy: 0.3715 - val_loss: 1.2530 - val_accuracy: 0.4914
# Epoch 25/50
# 26/26 [==============================] - 5s 143ms/step - loss: 2.2284 - accuracy: 0.3703 - val_loss: 1.3061 - val_accuracy: 0.4800
# Epoch 26/50
# 26/26 [==============================] - 4s 140ms/step - loss: 2.2230 - accuracy: 0.3655 - val_loss: 1.3024 - val_accuracy: 0.5143
# Epoch 27/50
# 26/26 [==============================] - 5s 143ms/step - loss: 2.1330 - accuracy: 0.3788 - val_loss: 1.2715 - val_accuracy: 0.5143
# Epoch 28/50
# 26/26 [==============================] - 4s 134ms/step - loss: 2.1904 - accuracy: 0.3872 - val_loss: 1.3403 - val_accuracy: 0.4686
# Epoch 29/50
# 26/26 [==============================] - 4s 136ms/step - loss: 2.0214 - accuracy: 0.3993 - val_loss: 1.1962 - val_accuracy: 0.5257
# Epoch 30/50
# 26/26 [==============================] - 5s 153ms/step - loss: 2.1837 - accuracy: 0.3776 - val_loss: 1.1560 - val_accuracy: 0.5029
# Epoch 31/50
# 26/26 [==============================] - 4s 140ms/step - loss: 2.1745 - accuracy: 0.3848 - val_loss: 1.1857 - val_accuracy: 0.5143
# Epoch 32/50
# 26/26 [==============================] - 4s 135ms/step - loss: 1.9499 - accuracy: 0.4101 - val_loss: 1.2121 - val_accuracy: 0.5200
# Epoch 33/50
# 26/26 [==============================] - 4s 139ms/step - loss: 2.0506 - accuracy: 0.4174 - val_loss: 1.2189 - val_accuracy: 0.4857
# Epoch 34/50
# 26/26 [==============================] - 4s 144ms/step - loss: 2.0255 - accuracy: 0.4150 - val_loss: 1.1819 - val_accuracy: 0.5143
# Epoch 35/50
# 26/26 [==============================] - 4s 135ms/step - loss: 2.1126 - accuracy: 0.3932 - val_loss: 1.1330 - val_accuracy: 0.5543
# Epoch 36/50
# 26/26 [==============================] - 4s 139ms/step - loss: 1.9799 - accuracy: 0.4198 - val_loss: 1.2032 - val_accuracy: 0.5143
# Epoch 37/50
# 26/26 [==============================] - 5s 152ms/step - loss: 1.9241 - accuracy: 0.4029 - val_loss: 1.1451 - val_accuracy: 0.5314
# Epoch 38/50
# 26/26 [==============================] - 4s 140ms/step - loss: 1.9941 - accuracy: 0.4198 - val_loss: 1.1998 - val_accuracy: 0.5143
# Epoch 39/50
# 26/26 [==============================] - 4s 136ms/step - loss: 1.8726 - accuracy: 0.4270 - val_loss: 1.1673 - val_accuracy: 0.5371
# Epoch 40/50
# 26/26 [==============================] - 4s 140ms/step - loss: 1.8731 - accuracy: 0.4355 - val_loss: 1.1195 - val_accuracy: 0.5314
# Epoch 41/50
# 26/26 [==============================] - 5s 145ms/step - loss: 2.0119 - accuracy: 0.4318 - val_loss: 1.1708 - val_accuracy: 0.5429
# Epoch 42/50
# 26/26 [==============================] - 4s 141ms/step - loss: 1.8509 - accuracy: 0.4439 - val_loss: 1.1415 - val_accuracy: 0.5429
# Epoch 43/50
# 26/26 [==============================] - 4s 139ms/step - loss: 1.8134 - accuracy: 0.4487 - val_loss: 1.1973 - val_accuracy: 0.5371
# Epoch 44/50
# 26/26 [==============================] - 5s 155ms/step - loss: 1.8872 - accuracy: 0.4186 - val_loss: 1.1499 - val_accuracy: 0.5600
# Epoch 45/50
# 26/26 [==============================] - 5s 145ms/step - loss: 1.7242 - accuracy: 0.4548 - val_loss: 1.1105 - val_accuracy: 0.5714
# Epoch 46/50
# 26/26 [==============================] - 5s 142ms/step - loss: 1.9286 - accuracy: 0.4234 - val_loss: 1.0997 - val_accuracy: 0.5771
# Epoch 47/50
# 26/26 [==============================] - 5s 142ms/step - loss: 1.7696 - accuracy: 0.4704 - val_loss: 1.0601 - val_accuracy: 0.5829
# Epoch 48/50
# 26/26 [==============================] - 5s 151ms/step - loss: 1.8387 - accuracy: 0.4403 - val_loss: 1.0672 - val_accuracy: 0.5886
# Epoch 49/50
# 26/26 [==============================] - 4s 141ms/step - loss: 1.8085 - accuracy: 0.4536 - val_loss: 1.0618 - val_accuracy: 0.5714
# Epoch 50/50
# 26/26 [==============================] - 4s 140ms/step - loss: 1.7610 - accuracy: 0.4560 - val_loss: 1.0580 - val_accuracy: 0.5771

# %% [markdown]
# ### Learning curves
#
# Let's take a look at the learning curves of the training and validation accuracy/loss when using the MobileNetV2 base model as a fixed feature extractor.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# Note: If you are wondering why the validation metrics are clearly better than the training metrics, the main factor is because layers like `tf.keras.layers.BatchNormalization` and `tf.keras.layers.Dropout` affect accuracy during training. They are turned off when calculating validation loss.
#
# To a lesser extent, it is also because training metrics report the average for an epoch, while validation metrics are evaluated after the epoch, so validation metrics see a model that has trained slightly longer.

# %% [markdown]
# ## Fine tuning
# In the feature extraction experiment, you were only training a few layers on top of an MobileNetV2 base model. The weights of the pre-trained network were **not** updated during training.
#
# One way to increase performance even further is to train (or "fine-tune") the weights of the top layers of the pre-trained model alongside the training of the classifier you added. The training process will force the weights to be tuned from generic feature maps to features associated specifically with the dataset.
#
# Note: This should only be attempted after you have trained the top-level classifier with the pre-trained model set to non-trainable. If you add a randomly initialized classifier on top of a pre-trained model and attempt to train all layers jointly, the magnitude of the gradient updates will be too large (due to the random weights from the classifier) and your pre-trained model will forget what it has learned.
#
# Also, you should try to fine-tune a small number of top layers rather than the whole MobileNet model. In most convolutional networks, the higher up a layer is, the more specialized it is. The first few layers learn very simple and generic features that generalize to almost all types of images. As you go higher up, the features are increasingly more specific to the dataset on which the model was trained. The goal of fine-tuning is to adapt these specialized features to work with the new dataset, rather than overwrite the generic learning.

# %% [markdown]
# ### Un-freeze the top layers of the model

# %% [markdown]
# All you need to do is unfreeze the `base_model` and set the bottom layers to be un-trainable. Then, you should recompile the model (necessary for these changes to take effect), and resume training.

# %%
base_model.trainable = True

# %%
# Let's take a look to see how many layers are in the base model
print("Number of layers in the base model: ", len(base_model.layers))

# Fine-tune from this layer onwards
fine_tune_at = 100

# Freeze all the layers before the `fine_tune_at` layer
for layer in base_model.layers[:fine_tune_at]:
  layer.trainable = False
# Out:
# Number of layers in the base model:  20

# %% [markdown]
# ### Compile the model
#
# As you are training a much larger model and want to readapt the pretrained weights, it is important to use a lower learning rate at this stage. Otherwise, your model could overfit very quickly.

# %%
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              optimizer = tf.keras.optimizers.RMSprop(learning_rate=base_learning_rate/10),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 160, 160, 3)]     0
#
#  sequential (Sequential)     (None, 160, 160, 3)       0
#
#  tf.math.truediv_2 (TFOpLamb  (None, 160, 160, 3)      0
#  da)
#
#  tf.math.subtract_2 (TFOpLam  (None, 160, 160, 3)      0
#  bda)
#
#  vggface_vgg16 (Functional)  (None, 512)               14714688
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 160)               82080
#
#  maxout (Maxout)             (None, 160)               0
#
#  batch_normalization (BatchN  (None, 160)              640
#  ormalization)
#
#  dropout_3 (Dropout)         (None, 160)               0
#
#  dense_3 (Dense)             (None, 5)                 805
#
# =================================================================
# Total params: 14,798,213
# Trainable params: 83,205
# Non-trainable params: 14,715,008
# _________________________________________________________________

# %%
len(model.trainable_variables)
# Out:
# 6

# %% [markdown]
# ### Continue training the model

# %% [markdown]
# If you trained to convergence earlier, this step will improve your accuracy by a few percentage points.

# %%
fine_tune_epochs = 50
total_epochs =  initial_epochs + fine_tune_epochs

history_fine = model.fit(train_dataset,
                         epochs=total_epochs,
                         initial_epoch=history.epoch[-1],
                         validation_data=validation_dataset)
# Out:
# Epoch 50/100
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 26/26 [==============================] - 9s 198ms/step - loss: 1.7667 - accuracy: 0.4415 - val_loss: 1.0372 - val_accuracy: 0.5771
# Epoch 51/100
# 26/26 [==============================] - 4s 135ms/step - loss: 1.7752 - accuracy: 0.4487 - val_loss: 1.1057 - val_accuracy: 0.5600
# Epoch 52/100
# 26/26 [==============================] - 4s 141ms/step - loss: 1.8668 - accuracy: 0.4499 - val_loss: 1.0914 - val_accuracy: 0.5600
# Epoch 53/100
# 26/26 [==============================] - 5s 155ms/step - loss: 1.7788 - accuracy: 0.4801 - val_loss: 1.0632 - val_accuracy: 0.5943
# Epoch 54/100
# 26/26 [==============================] - 4s 135ms/step - loss: 1.8440 - accuracy: 0.4475 - val_loss: 1.0433 - val_accuracy: 0.5886
# Epoch 55/100
# 26/26 [==============================] - 5s 152ms/step - loss: 1.8128 - accuracy: 0.4451 - val_loss: 1.0445 - val_accuracy: 0.5714
# Epoch 56/100
# 26/26 [==============================] - 4s 138ms/step - loss: 1.8018 - accuracy: 0.4499 - val_loss: 1.0527 - val_accuracy: 0.5943
# Epoch 57/100
# 26/26 [==============================] - 5s 146ms/step - loss: 1.8287 - accuracy: 0.4355 - val_loss: 1.0551 - val_accuracy: 0.5829
# Epoch 58/100
# 26/26 [==============================] - 4s 141ms/step - loss: 1.7780 - accuracy: 0.4668 - val_loss: 1.0776 - val_accuracy: 0.5657
# Epoch 59/100
# 26/26 [==============================] - 5s 153ms/step - loss: 1.8190 - accuracy: 0.4511 - val_loss: 1.0807 - val_accuracy: 0.5657
# Epoch 60/100
# 26/26 [==============================] - 4s 140ms/step - loss: 1.8143 - accuracy: 0.4644 - val_loss: 1.0901 - val_accuracy: 0.5600
# Epoch 61/100
# 26/26 [==============================] - 4s 139ms/step - loss: 1.7699 - accuracy: 0.4403 - val_loss: 1.0482 - val_accuracy: 0.5771
# Epoch 62/100
# 26/26 [==============================] - 5s 152ms/step - loss: 1.7443 - accuracy: 0.4656 - val_loss: 1.0277 - val_accuracy: 0.5886
# Epoch 63/100
# 26/26 [==============================] - 4s 141ms/step - loss: 1.7633 - accuracy: 0.4620 - val_loss: 1.0296 - val_accuracy: 0.5886
# Epoch 64/100
# 26/26 [==============================] - 4s 136ms/step - loss: 1.7510 - accuracy: 0.4668 - val_loss: 1.0704 - val_accuracy: 0.5657
# Epoch 65/100
# 26/26 [==============================] - 4s 140ms/step - loss: 1.7139 - accuracy: 0.4584 - val_loss: 1.0992 - val_accuracy: 0.5543
# Epoch 66/100
# 26/26 [==============================] - 5s 137ms/step - loss: 1.8282 - accuracy: 0.4560 - val_loss: 1.0294 - val_accuracy: 0.5943
# Epoch 67/100
# 26/26 [==============================] - 4s 138ms/step - loss: 1.8587 - accuracy: 0.4403 - val_loss: 1.1370 - val_accuracy: 0.5486
# Epoch 68/100
# 26/26 [==============================] - 4s 141ms/step - loss: 1.7752 - accuracy: 0.4765 - val_loss: 1.0648 - val_accuracy: 0.5771
# Epoch 69/100
# 26/26 [==============================] - 4s 140ms/step - loss: 1.8096 - accuracy: 0.4608 - val_loss: 1.0487 - val_accuracy: 0.5771
# Epoch 70/100
# 26/26 [==============================] - 5s 142ms/step - loss: 1.8170 - accuracy: 0.4379 - val_loss: 1.0386 - val_accuracy: 0.5943
# Epoch 71/100
# 26/26 [==============================] - 4s 143ms/step - loss: 1.8015 - accuracy: 0.4403 - val_loss: 1.0461 - val_accuracy: 0.5829
# Epoch 72/100
# 26/26 [==============================] - 4s 138ms/step - loss: 1.7690 - accuracy: 0.4487 - val_loss: 1.0577 - val_accuracy: 0.5771
# Epoch 73/100
# 26/26 [==============================] - 4s 140ms/step - loss: 1.7979 - accuracy: 0.4584 - val_loss: 1.0513 - val_accuracy: 0.5771
# Epoch 74/100
# 26/26 [==============================] - 4s 139ms/step - loss: 1.7454 - accuracy: 0.4596 - val_loss: 1.0653 - val_accuracy: 0.5829
# Epoch 75/100
# 26/26 [==============================] - 4s 138ms/step - loss: 1.7522 - accuracy: 0.4777 - val_loss: 1.0183 - val_accuracy: 0.6057
# Epoch 76/100
# 26/26 [==============================] - 5s 150ms/step - loss: 1.6915 - accuracy: 0.4692 - val_loss: 1.0490 - val_accuracy: 0.5771
# Epoch 77/100
# 26/26 [==============================] - 4s 138ms/step - loss: 1.6538 - accuracy: 0.4692 - val_loss: 1.0838 - val_accuracy: 0.5600
# Epoch 78/100
# 26/26 [==============================] - 4s 139ms/step - loss: 1.9233 - accuracy: 0.4294 - val_loss: 1.0354 - val_accuracy: 0.5886
# Epoch 79/100
# 26/26 [==============================] - 4s 139ms/step - loss: 1.6500 - accuracy: 0.4922 - val_loss: 1.0739 - val_accuracy: 0.5829
# Epoch 80/100
# 26/26 [==============================] - 4s 138ms/step - loss: 1.7971 - accuracy: 0.4499 - val_loss: 1.0351 - val_accuracy: 0.5943
# Epoch 81/100
# 26/26 [==============================] - 4s 140ms/step - loss: 1.8072 - accuracy: 0.4536 - val_loss: 1.0605 - val_accuracy: 0.5771
# Epoch 82/100
# 26/26 [==============================] - 4s 140ms/step - loss: 1.8214 - accuracy: 0.4536 - val_loss: 1.0797 - val_accuracy: 0.5771
# Epoch 83/100
# 26/26 [==============================] - 4s 140ms/step - loss: 1.8184 - accuracy: 0.4524 - val_loss: 1.0393 - val_accuracy: 0.5829
# Epoch 84/100
# 26/26 [==============================] - 4s 139ms/step - loss: 1.8022 - accuracy: 0.4427 - val_loss: 1.0607 - val_accuracy: 0.5771
# Epoch 85/100
# 26/26 [==============================] - 4s 138ms/step - loss: 1.7462 - accuracy: 0.4656 - val_loss: 1.0339 - val_accuracy: 0.6000
# Epoch 86/100
# 26/26 [==============================] - 5s 151ms/step - loss: 1.6842 - accuracy: 0.4765 - val_loss: 1.0609 - val_accuracy: 0.5600
# Epoch 87/100
# 26/26 [==============================] - 4s 136ms/step - loss: 1.9022 - accuracy: 0.4138 - val_loss: 1.0430 - val_accuracy: 0.5886
# Epoch 88/100
# 26/26 [==============================] - 4s 137ms/step - loss: 1.7228 - accuracy: 0.4620 - val_loss: 1.0334 - val_accuracy: 0.5943
# Epoch 89/100
# 26/26 [==============================] - 4s 139ms/step - loss: 1.8025 - accuracy: 0.4608 - val_loss: 0.9929 - val_accuracy: 0.6057
# Epoch 90/100
# 26/26 [==============================] - 5s 149ms/step - loss: 1.7211 - accuracy: 0.4692 - val_loss: 1.0117 - val_accuracy: 0.6171
# Epoch 91/100
# 26/26 [==============================] - 4s 140ms/step - loss: 1.7519 - accuracy: 0.4318 - val_loss: 1.0633 - val_accuracy: 0.5657
# Epoch 92/100
# 26/26 [==============================] - 4s 136ms/step - loss: 1.8126 - accuracy: 0.4536 - val_loss: 1.0516 - val_accuracy: 0.5771
# Epoch 93/100
# 26/26 [==============================] - 4s 140ms/step - loss: 1.6901 - accuracy: 0.4632 - val_loss: 1.0593 - val_accuracy: 0.5829
# Epoch 94/100
# 26/26 [==============================] - 4s 134ms/step - loss: 1.7319 - accuracy: 0.4524 - val_loss: 1.0576 - val_accuracy: 0.5657
# Epoch 95/100
# 26/26 [==============================] - 4s 139ms/step - loss: 1.7327 - accuracy: 0.4837 - val_loss: 1.0212 - val_accuracy: 0.5943
# Epoch 96/100
# 26/26 [==============================] - 4s 138ms/step - loss: 1.6737 - accuracy: 0.4922 - val_loss: 1.0216 - val_accuracy: 0.5829
# Epoch 97/100
# 26/26 [==============================] - 4s 140ms/step - loss: 1.6259 - accuracy: 0.4765 - val_loss: 0.9959 - val_accuracy: 0.6114
# Epoch 98/100
# 26/26 [==============================] - 4s 135ms/step - loss: 1.7009 - accuracy: 0.4584 - val_loss: 1.0132 - val_accuracy: 0.5943
# Epoch 99/100
# 26/26 [==============================] - 4s 141ms/step - loss: 1.8184 - accuracy: 0.4487 - val_loss: 0.9817 - val_accuracy: 0.6057
# Epoch 100/100
# 26/26 [==============================] - 5s 151ms/step - loss: 1.7705 - accuracy: 0.4608 - val_loss: 0.9500 - val_accuracy: 0.6171

# %% [markdown]
# Let's take a look at the learning curves of the training and validation accuracy/loss when fine-tuning the last few layers of the MobileNetV2 base model and training the classifier on top of it. The validation loss is much higher than the training loss, so you may get some overfitting.
#
# You may also get some overfitting as the new training set is relatively small and similar to the original MobileNetV2 datasets.

# %% [markdown]
# After fine tuning the model nearly reaches 98% accuracy on the validation set.

# %%
acc += history_fine.history['accuracy']
val_acc += history_fine.history['val_accuracy']

loss += history_fine.history['loss']
val_loss += history_fine.history['val_loss']

# %%
plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.ylim([0.8, 1])
plt.plot([initial_epochs-1,initial_epochs-1],
          plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.ylim([0, 1.0])
plt.plot([initial_epochs-1,initial_epochs-1],
         plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# ### Evaluation and prediction

# %% [markdown]
# Finally you can verify the performance of the model on new data using test set.

# %%
loss, accuracy = model.evaluate(test_dataset)
print('Test accuracy :', accuracy)
# Out:
# 1/1 [==============================] - 1s 642ms/step - loss: 1.2498 - accuracy: 0.5312
# Test accuracy : 0.53125

# %% [markdown]
# ## Summary
#
# * **Using a pre-trained model for feature extraction**:  When working with a small dataset, it is a common practice to take advantage of features learned by a model trained on a larger dataset in the same domain. This is done by instantiating the pre-trained model and adding a fully-connected classifier on top. The pre-trained model is "frozen" and only the weights of the classifier get updated during training.
# In this case, the convolutional base extracted all the features associated with each image and you just trained a classifier that determines the image class given that set of extracted features.
#
# * **Fine-tuning a pre-trained model**: To further improve performance, one might want to repurpose the top-level layers of the pre-trained models to the new dataset via fine-tuning.
# In this case, you tuned your weights such that your model learned high-level features specific to the dataset. This technique is usually recommended when the training dataset is large and very similar to the original dataset that the pre-trained model was trained on.
#
# To learn more, visit the [Transfer learning guide](https://www.tensorflow.org/guide/keras/transfer_learning).
